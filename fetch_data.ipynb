# %% [markdown]
# I retrieved the data for financial statements and stock prices via the Yahoo Finance API.

# %%
pip install yfinance
# Out:
# ...
#
# [notice] A new release of pip is available: 23.3.2 -> 24.0
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
# !pip install yahoofinancials
# Out:
# ...
#
# [notice] A new release of pip is available: 23.3.2 -> 24.0
# [notice] To update, run: pip install --upgrade pip

# %%
import yfinance as yf
sedg = yf.Ticker("SEDG")

# %% [markdown]
# Fatch the data for income statements (quarter and annual) for SolarEdge

# %%
sedg_quarter_income_stmt = sedg.quarterly_income_stmt
sedg_quarter_income_stmt.to_csv('sedg_income_stmt.csv')

# %%
sedg_annual_income_stmt = sedg.income_stmt
sedg_annual_income_stmt.to_csv('sedg_annual_income_stmt.csv')

# %% [markdown]
# Fatch the data for income statements (quarter and annual) for Enphase Energy

# %%
enph = yf.Ticker("ENPH")

enph_quarter_income_stmt = enph.quarterly_income_stmt
enph_quarter_income_stmt.to_csv('enph__quarter_income_stmt.csv')

enph_annual_income_stmt = enph.income_stmt
enph_annual_income_stmt.to_csv('enph_annual_income_stmt.csv')

# %% [markdown]
# Fatch the data balance sheet (quarter and annual) for SolarEdge

# %%
sedg_quarter_balance_sheet = sedg.quarterly_balance_sheet
sedg_quarter_balance_sheet.to_csv('sedg_balance_sheet.csv')

sedg_annual_balance_sheet = sedg.balance_sheet
sedg_annual_balance_sheet.to_csv('sedg_annual_balance_sheet.csv')

# %% [markdown]
# Fatch the data balance sheet (quarter and annual) for Enphase Energy

# %%
enph_quarter_balance_sheet = enph.quarterly_balance_sheet
enph_quarter_balance_sheet.to_csv('enph__quarter_balance_sheet.csv')

enph_annual_balance_sheet = enph.balance_sheet
enph_annual_balance_sheet.to_csv('enph_annual_balance_sheet.csv')

# %% [markdown]
# Fatch the data for income statements (quarter and annual) for Sun Power

# %%
spwr = yf.Ticker("SPWR")

spwr_quarter_income_stmt = spwr.quarterly_income_stmt
spwr_quarter_income_stmt.to_csv('spwr__quarter_income_stmt.csv')

spwr_annual_income_stmt = spwr.income_stmt
spwr_annual_income_stmt.to_csv('spwr_annual_income_stmt.csv')

# %% [markdown]
# Fatch the data balance sheet (quarter and annual) for Sun Power

# %%
spwr_quarter_balance_sheet = spwr.quarterly_balance_sheet
spwr_quarter_balance_sheet.to_csv('spwr__quarter_balance_sheet.csv')

spwr_annual_balance_sheet = spwr.balance_sheet
spwr_annual_balance_sheet.to_csv('spwr_annual_balance_sheet.csv')

# %% [markdown]
# Fatch the data for income statements (quarter and annual) for First Solar

# %%
fslr = yf.Ticker("FSLR")

fslr_quarter_income_stmt = fslr.quarterly_income_stmt
fslr_quarter_income_stmt.to_csv('fslr__quarter_income_stmt.csv')

fslr_annual_income_stmt = fslr.income_stmt
fslr_annual_income_stmt.to_csv('fslr_annual_income_stmt.csv')

# %% [markdown]
# Fatch the data balance sheet (quarter and annual) for First Solar

# %%
fslr_quarter_balance_sheet = fslr.quarterly_balance_sheet
fslr_quarter_balance_sheet.to_csv('fslr__quarter_balance_sheet.csv')

fslr_annual_balance_sheet = fslr.balance_sheet
fslr_annual_balance_sheet.to_csv('fslr_annual_balance_sheet.csv')

# %% [markdown]
# Fatch the data stock prices for all companies

# %%
data = yf.download("SEDG ENPH SPWR", start="2017-01-01", end="2024-01-31")
data
# Out:
# [*********************100%%**********************]  3 of 3 completed
# Price        Adj Close                            Close                       \
# Ticker            ENPH       SEDG      SPWR        ENPH       SEDG      SPWR
# Date
# 2017-01-03    1.050000  13.200000  4.485920    1.050000  13.200000  4.485920
# 2017-01-04    1.150000  14.400000  4.636542    1.150000  14.400000  4.636542
# 2017-01-05    1.120000  13.800000  4.669286    1.120000  13.800000  4.669286
# 2017-01-06    1.110000  13.750000  4.616896    1.110000  13.750000  4.616896
# 2017-01-09    1.110000  13.500000  4.682384    1.110000  13.500000  4.682384
# ...                ...        ...       ...         ...        ...       ...
# 2024-01-24  108.070000  70.199997  3.210000  108.070000  70.199997  3.210000
# 2024-01-25  106.830002  70.440002  3.280000  106.830002  70.440002  3.280000
# 2024-01-26  105.370003  68.839996  3.200000  105.370003  68.839996  3.200000
# ...

# %%
data = yf.download("SEDG ENPH SPWR", start="2017-01-01",
                    end="2024-01-31", group_by='tickers')
data
# Out:
# [*********************100%%**********************]  3 of 3 completed
# Ticker            ENPH                                                  \
# Price             Open        High         Low       Close   Adj Close
# Date
# 2017-01-03    1.020000    1.050000    1.010000    1.050000    1.050000
# 2017-01-04    1.090000    1.150000    1.050000    1.150000    1.150000
# 2017-01-05    1.190000    1.190000    1.110000    1.120000    1.120000
# 2017-01-06    1.120000    1.140000    1.080000    1.110000    1.110000
# 2017-01-09    1.100000    1.110000    1.080000    1.110000    1.110000
# ...                ...         ...         ...         ...         ...
# 2024-01-24  114.379997  114.639999  108.050003  108.070000  108.070000
# 2024-01-25  109.180000  110.099998  103.720001  106.830002  106.830002
# 2024-01-26  107.699997  109.449997  104.970001  105.370003  105.370003
# 2024-01-29  105.230003  109.440002  103.440002  109.169998  109.169998
# ...

# %%
data.to_csv('historical_data.csv')

# %%
pip install pandas-datareader
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 109.5/109.5 kB 831.8 kB/s eta 0:00:00a 0:00:01
# ...
#
# [notice] A new release of pip is available: 23.3.2 -> 24.0
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('whitegrid')
plt.style.use("fivethirtyeight")
# %matplotlib inline

# For reading stock data from yahoo
from pandas_datareader.data import DataReader
import yfinance as yf
from pandas_datareader import data as pdr

yf.pdr_override()

# For time stamps
from datetime import datetime


# The tech stocks we'll use for this analysis
tech_list = ['SEDG', 'ENPH', 'SPWR', 'FSLR']

# Set up End and Start times for data grab
tech_list = ['SEDG', 'ENPH', 'SPWR', 'FSLR']

end = datetime.now()
start = "2017-01-01"

for stock in tech_list:
    globals()[stock] = yf.download(stock, start, end)
    

company_list = [SEDG, ENPH, SPWR, FSLR]
company_name = ["Solaredge", "Enphase Energy", "SunPower", "First Solar"]

for company, com_name in zip(company_list, company_name):
    company["company_name"] = com_name
    
df = pd.concat(company_list, axis=0)
df.tail(10)
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2024-01-22  148.490005  159.229996  147.940002  149.910004  149.910004
# 2024-01-23  153.880005  157.669998  149.800003  151.460007  151.460007
# 2024-01-24  153.539993  154.130005  148.250000  148.869995  148.869995
# 2024-01-25  150.190002  151.279999  145.910004  149.229996  149.229996
# 2024-01-26  149.059998  150.649994  147.419998  147.830002  147.830002
# 2024-01-29  146.990005  149.330002  144.330002  149.300003  149.300003
# 2024-01-30  148.399994  150.750000  146.490005  149.029999  149.029999
# 2024-01-31  149.000000  154.919998  146.050003  146.300003  146.300003
# ...

# %%
df.to_csv('stock_prices.csv')

# %%
# The tech stocks we'll use for this analysis
tech_list = ['SEDG']

# Set up End and Start times for data grab
tech_list = ['SEDG']

end = datetime.now()
start = "2017-01-01"

for stock in tech_list:
    globals()[stock] = yf.download(stock, start, end)
    

company_list = [SEDG]
company_name = ["Solaredge"]

for company, com_name in zip(company_list, company_name):
    company["company_name"] = com_name
    
df = pd.concat(company_list, axis=0)
df.tail(10)

df.to_csv('stock_prices_sedg.csv')
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
# The tech stocks we'll use for this analysis
tech_list = ['ENPH']

# Set up End and Start times for data grab
tech_list = ['ENPH']

end = datetime.now()
start = "2017-01-01"

for stock in tech_list:
    globals()[stock] = yf.download(stock, start, end)
    

company_list = [ENPH]
company_name = ["Enphase Energy"]

for company, com_name in zip(company_list, company_name):
    company["company_name"] = com_name
    
df = pd.concat(company_list, axis=0)
df.tail(10)

df.to_csv('stock_prices_enph.csv')
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
# The tech stocks we'll use for this analysis
tech_list = ['SPWR']

# Set up End and Start times for data grab
tech_list = ['SPWR']

end = datetime.now()
start = "2017-01-01"

for stock in tech_list:
    globals()[stock] = yf.download(stock, start, end)
    

company_list = [SPWR]
company_name = ["SunPower"]

for company, com_name in zip(company_list, company_name):
    company["company_name"] = com_name
    
df = pd.concat(company_list, axis=0)
df.tail(10)

df.to_csv('stock_prices_spwr.csv')
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
# The tech stocks we'll use for this analysis
tech_list = ['FSLR']

# Set up End and Start times for data grab
tech_list = ['FSLR']

end = datetime.now()
start = "2017-01-01"

for stock in tech_list:
    globals()[stock] = yf.download(stock, start, end)
    

company_list = [FSLR]
company_name = ["First Solar"]

for company, com_name in zip(company_list, company_name):
    company["company_name"] = com_name
    
df = pd.concat(company_list, axis=0)
df.tail(10)

df.to_csv('stock_prices_fslr.csv')
# Out:
# [*********************100%%**********************]  1 of 1 completed
