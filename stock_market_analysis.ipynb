# %% [markdown]
# Analyzing the solar industry, I've chosen to focus on four key companies: SolarEdge, Enphase Energy, SunPower, and First Solar. This selection allows for a comprehensive exploration of the market, as these companies represent prominent key players in the solar energy sector.
#
# The decision to delve into the solar industry stems from its increasing significance in the global energy landscape. With growing concerns about climate change and the transition towards renewable energy sources, understanding the dynamics and trends within the solar sector is crucial. Moreover, solar energy presents a promising avenue for sustainable development, offering environmentally friendly alternatives to traditional energy sources.
#
# By analyzing these companies, I aim to gain insights into various aspects of the solar industry, including market trends, financial performance, and the broader impact of solar energy adoption.

# %% [markdown]
# Solaredge

# %%
import pandas as pd
sedg = pd.read_csv(r'/Users/admin/Desktop/python/final_project/data/stock prices/stock_prices_sedg.csv')

# %%
sedg.describe().T
# Out:
#             count          mean           std        min            25%  \
# Open       1783.0  1.544108e+02  1.134392e+02      12.40      45.350000
# High       1783.0  1.582997e+02  1.163748e+02      12.65      46.055000
# Low        1783.0  1.503506e+02  1.103489e+02      12.25      44.255001
# Close      1783.0  1.543395e+02  1.133292e+02      12.30      45.369999
# Adj Close  1783.0  1.543395e+02  1.133292e+02      12.30      45.369999
# Volume     1783.0  1.135476e+06  1.118551e+06  168000.00  610650.000000
#
#                      50%           75%           max
# Open          109.989998  2.729500e+02  3.741000e+02
# High          113.019997  2.795400e+02  3.897100e+02
# Low           107.415001  2.657450e+02  3.600000e+02
# Close         109.790001  2.729150e+02  3.683300e+02
# Adj Close     109.790001  2.729150e+02  3.683300e+02
# Volume     863000.000000  1.260600e+06  2.130420e+07

# %%
sedg.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1783 entries, 0 to 1782
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Date          1783 non-null   object
#  1   Open          1783 non-null   float64
#  2   High          1783 non-null   float64
#  3   Low           1783 non-null   float64
#  4   Close         1783 non-null   float64
#  5   Adj Close     1783 non-null   float64
#  6   Volume        1783 non-null   int64
#  7   company_name  1783 non-null   object
# dtypes: float64(5), int64(1), object(2)
# memory usage: 111.6+ KB

# %% [markdown]
# Check for missing data and duplicates

# %%
missing_values = sedg.isnull().sum()
duplicated_rows = sedg.duplicated().sum()

print("Missing Values:")
print(missing_values[missing_values > 0])

print("\nNumber of Duplicated Rows:", duplicated_rows)
# Out:
# Missing Values:
# Series([], dtype: int64)
#
# Number of Duplicated Rows: 0

# %% [markdown]
# No duplicates or missing data detected.

# %%
sedg.dtypes
# Out:
# Date             object
# Open            float64
# High            float64
# Low             float64
# Close           float64
# Adj Close       float64
# Volume            int64
# company_name     object
# dtype: object

# %% [markdown]
# Convert the 'Date' column in the DataFrame to the datetime data type

# %%
sedg['Date'] = pd.to_datetime(sedg['Date'])

# %% [markdown]
# Enphase Energy

# %%
enph = pd.read_csv(r'/Users/admin/Desktop/python/final_project/data/stock prices/stock_prices_enph.csv')
enph.head()
# Out:
#          Date  Open  High   Low  Close  Adj Close  Volume    company_name
# 0  2017-01-03  1.02  1.05  1.01   1.05       1.05  445900  Enphase Energy
# 1  2017-01-04  1.09  1.15  1.05   1.15       1.15  903000  Enphase Energy
# 2  2017-01-05  1.19  1.19  1.11   1.12       1.12  308700  Enphase Energy
# 3  2017-01-06  1.12  1.14  1.08   1.11       1.11  259700  Enphase Energy
# 4  2017-01-09  1.10  1.11  1.08   1.11       1.11  180000  Enphase Energy

# %%
enph.describe().T
# Out:
#             count          mean           std       min         25%  \
# Open       1783.0  9.399020e+01  9.218079e+01      0.70        5.54
# High       1783.0  9.662018e+01  9.458146e+01      0.71        5.74
# Low        1783.0  9.126108e+01  8.957153e+01      0.65        5.37
# Close      1783.0  9.393734e+01  9.205973e+01      0.70        5.59
# Adj Close  1783.0  9.393734e+01  9.205973e+01      0.70        5.59
# Volume     1783.0  3.307231e+06  3.108719e+06  95700.00  1671800.00
#
#                   50%           75%           max
# Open            60.84  1.692200e+02  3.340100e+02
# High            61.93  1.742000e+02  3.399200e+02
# Low             58.59  1.635150e+02  3.263100e+02
# Close           59.93  1.687200e+02  3.360000e+02
# Adj Close       59.93  1.687200e+02  3.360000e+02
# Volume     2770500.00  4.014900e+06  5.517290e+07

# %%
enph.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1783 entries, 0 to 1782
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Date          1783 non-null   object
#  1   Open          1783 non-null   float64
#  2   High          1783 non-null   float64
#  3   Low           1783 non-null   float64
#  4   Close         1783 non-null   float64
#  5   Adj Close     1783 non-null   float64
#  6   Volume        1783 non-null   int64
#  7   company_name  1783 non-null   object
# dtypes: float64(5), int64(1), object(2)
# memory usage: 111.6+ KB

# %% [markdown]
# Check for missing data and duplicates

# %%
missing_values = enph.isnull().sum()
duplicated_rows = enph.duplicated().sum()

print("Missing Values:")
print(missing_values[missing_values > 0])

print("\nNumber of Duplicated Rows:", duplicated_rows)
# Out:
# Missing Values:
# Series([], dtype: int64)
#
# Number of Duplicated Rows: 0

# %% [markdown]
# No duplicates or missing data detected.

# %%
enph.dtypes
# Out:
# Date             object
# Open            float64
# High            float64
# Low             float64
# Close           float64
# Adj Close       float64
# Volume            int64
# company_name     object
# dtype: object

# %% [markdown]
# Convert the 'Date' column in the DataFrame to the datetime data type

# %%
enph['Date'] = pd.to_datetime(enph['Date'])

# %% [markdown]
# Sun Power

# %%
spwr = pd.read_csv(r'/Users/admin/Desktop/python/final_project/data/stock prices/stock_prices_spwr.csv')
spwr.head()
# Out:
#          Date      Open      High       Low     Close  Adj Close   Volume  \
# 0  2017-01-03  4.394237  4.505566  4.322200  4.485920   4.485920  5370612
# 1  2017-01-04  4.505566  4.767518  4.499018  4.636542   4.636542  7899476
# 2  2017-01-05  4.636542  4.728225  4.564506  4.669286   4.669286  7246073
# 3  2017-01-06  4.649640  4.734774  4.610347  4.616896   4.616896  2912753
# 4  2017-01-09  4.623445  4.767518  4.571054  4.682384   4.682384  2894123
#
#   company_name
# 0     SunPower
# 1     SunPower
# 2     SunPower
# 3     SunPower
# 4     SunPower

# %%
spwr.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1783 entries, 0 to 1782
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Date          1783 non-null   object
#  1   Open          1783 non-null   float64
#  2   High          1783 non-null   float64
#  3   Low           1783 non-null   float64
#  4   Close         1783 non-null   float64
#  5   Adj Close     1783 non-null   float64
#  6   Volume        1783 non-null   int64
#  7   company_name  1783 non-null   object
# dtypes: float64(5), int64(1), object(2)
# memory usage: 111.6+ KB

# %%
spwr.describe().T
# Out:
#             count          mean           std            min           25%  \
# Open       1783.0  1.187274e+01  9.278323e+00       2.810000  4.848052e+00
# High       1783.0  1.226913e+01  9.655154e+00       2.980000  4.996726e+00
# Low        1783.0  1.148156e+01  8.889057e+00       2.639162  4.732387e+00
# Close      1783.0  1.186504e+01  9.284754e+00       2.940000  4.862475e+00
# Adj Close  1783.0  1.186504e+01  9.284754e+00       2.940000  4.862475e+00
# Volume     1783.0  4.744600e+06  3.424660e+06  889936.000000  2.739200e+06
#
#                     50%           75%           max
# Open       6.502947e+00  1.801500e+01  5.420000e+01
# High       6.764898e+00  1.848500e+01  5.752000e+01
# Low        6.313032e+00  1.743000e+01  5.055000e+01
# Close      6.529142e+00  1.799000e+01  5.401000e+01
# Adj Close  6.529142e+00  1.799000e+01  5.401000e+01
# Volume     3.719800e+06  5.440614e+06  4.803320e+07

# %%
missing_values = spwr.isnull().sum()
duplicated_rows = spwr.duplicated().sum()

print("Missing Values:")
print(missing_values[missing_values > 0])

print("\nNumber of Duplicated Rows:", duplicated_rows)
# Out:
# Missing Values:
# Series([], dtype: int64)
#
# Number of Duplicated Rows: 0

# %% [markdown]
# No duplicates or missing data detected.

# %% [markdown]
# Convert the 'Date' column in the DataFrame to the datetime data type

# %%
spwr['Date'] = pd.to_datetime(spwr['Date'])

# %% [markdown]
# First Solar

# %%
fslr = pd.read_csv(r'/Users/admin/Desktop/python/final_project/data/stock prices/stock_prices_fslr.csv')
fslr.head()
# Out:
#          Date       Open       High        Low      Close  Adj Close   Volume  \
# 0  2017-01-03  32.610001  33.660000  32.099998  33.540001  33.540001  2664800
# 1  2017-01-04  33.689999  34.509998  33.599998  34.169998  34.169998  2478500
# 2  2017-01-05  33.869999  34.160000  33.500000  33.880001  33.880001  1954900
# 3  2017-01-06  34.070000  34.080002  33.299999  33.320000  33.320000  1277400
# 4  2017-01-09  33.380001  33.700001  33.020000  33.570000  33.570000  1217500
#
#   company_name
# 0  First Solar
# 1  First Solar
# 2  First Solar
# 3  First Solar
# 4  First Solar

# %%
fslr.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1783 entries, 0 to 1782
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Date          1783 non-null   object
#  1   Open          1783 non-null   float64
#  2   High          1783 non-null   float64
#  3   Low           1783 non-null   float64
#  4   Close         1783 non-null   float64
#  5   Adj Close     1783 non-null   float64
#  6   Volume        1783 non-null   int64
#  7   company_name  1783 non-null   object
# dtypes: float64(5), int64(1), object(2)
# memory usage: 111.6+ KB

# %%
fslr.describe().T
# Out:
#             count          mean           std            min           25%  \
# Open       1783.0  8.540339e+01  4.758200e+01      26.040001  5.205000e+01
# High       1783.0  8.709519e+01  4.855046e+01      27.000000  5.277000e+01
# Low        1783.0  8.366246e+01  4.653165e+01      25.559999  5.123000e+01
# Close      1783.0  8.536468e+01  4.753238e+01      26.330000  5.196000e+01
# Adj Close  1783.0  8.536468e+01  4.753238e+01      26.330000  5.196000e+01
# Volume     1783.0  2.095013e+06  1.728126e+06  290700.000000  1.181400e+06
#
#                     50%           75%           max
# Open       6.910000e+01  1.002300e+02  2.280800e+02
# High       7.020000e+01  1.021250e+02  2.320000e+02
# Low        6.764000e+01  9.794500e+01  2.212600e+02
# Close      6.915000e+01  9.970500e+01  2.316900e+02
# Adj Close  6.915000e+01  9.970500e+01  2.316900e+02
# Volume     1.645800e+06  2.458550e+06  2.387110e+07

# %%
missing_values = fslr.isnull().sum()
duplicated_rows = fslr.duplicated().sum()

print("Missing Values:")
print(missing_values[missing_values > 0])

print("\nNumber of Duplicated Rows:", duplicated_rows)
# Out:
# Missing Values:
# Series([], dtype: int64)
#
# Number of Duplicated Rows: 0

# %% [markdown]
# No duplicates or missing data detected.

# %% [markdown]
# Convert the 'Date' column in the DataFrame to the datetime data type

# %%
fslr['Date'] = pd.to_datetime(fslr['Date'])

# %%
fslr.dtypes #check
# Out:
# Date            datetime64[ns]
# Open                   float64
# High                   float64
# Low                    float64
# Close                  float64
# Adj Close              float64
# Volume                   int64
# company_name            object
# dtype: object

# %% [markdown]
# Merging all the companies together

# %%
df = pd.read_csv(r'/Users/admin/Desktop/python/final_project/data/stock prices/stock_prices.csv')
df.head()
# Out:
#          Date   Open    High     Low  Close  Adj Close   Volume company_name
# 0  2017-01-03  12.55  13.200  12.550  13.20      13.20  1123600    Solaredge
# 1  2017-01-04  13.30  14.450  13.300  14.40      14.40  1363300    Solaredge
# 2  2017-01-05  14.30  14.575  13.775  13.80      13.80   647700    Solaredge
# 3  2017-01-06  13.90  14.000  13.600  13.75      13.75   537300    Solaredge
# 4  2017-01-09  13.70  13.700  13.150  13.50      13.50   733400    Solaredge

# %% [markdown]
# Convert the 'Date' column in the DataFrame to the datetime data type

# %%
df['Date'] = pd.to_datetime(df['Date'])

# %%
df.dtypes #check
# Out:
# Date            datetime64[ns]
# Open                   float64
# High                   float64
# Low                    float64
# Close                  float64
# Adj Close              float64
# Volume                   int64
# company_name            object
# dtype: object

# %% [markdown]
# Closing Price

# %% [markdown]
# The closing price is the last price at which the stock is traded during the regular trading day. A stock’s closing price is the standard benchmark used by investors to track its performance over time.

# %%
import matplotlib.pyplot as plt
from matplotlib.dates import YearLocator, DateFormatter
# Use dark background style
plt.style.use('dark_background')
# List of unique companies in the 'company_name' column
company_list = df['company_name'].unique()

# Set up the plot
plt.figure(figsize=(15, 10))
plt.subplots_adjust(top=1.25, bottom=1.2)

# Iterate over each company
for i, company in enumerate(company_list, 1):
    plt.subplot(2, 2, i)
    
    # Filter data for the current company
    company_data = df[df['company_name'] == company]
    
    # Plot the 'Adj Close' column with the original 'Date' values
    plt.plot(company_data['Date'], company_data['Adj Close'])
    
    plt.ylabel('Adj Close')
    plt.xlabel(None)
    plt.title(f"Closing Price of {company}")

    # Set x-axis tick frequency to display years only
    plt.gca().xaxis.set_major_locator(YearLocator())
    plt.gca().xaxis.set_major_formatter(DateFormatter('%Y'))

plt.tight_layout()
plt.show()

# %% [markdown]
# In the solar energy sector, encompassing SolarEdge, Enphase Energy, SunPower, and First Solar, a notable upsurge was observed from 2020 to 2021, after onset of the Coronavirus pandemic, signifying a pinnacle in the green energy industry's growth trajectory. However, subsequent years witnessed a downturn, notably evident in the last year (2023) and extending into the present period (February 2024), characterized by a substantial decline gripping the industry.
#
# This project aims to probe the fundamental factors underlying the downturn in the solar energy industry's stock prices during this period. Importantly, the decline appears to impact the entire industry rather than being confined to specific companies. This observation underscores the importance of comprehending broader market dynamics and external influences that affect the industry holistically.
#
# Through this analysis, we seek to ascertain the root causes of this industry-wide decline by exploring various potential factors.

# %% [markdown]
# The high and low prices over time for four companies

# %%
import matplotlib.dates as mdates

# List of unique companies
company_list = df['company_name'].unique()

# Set up the plot
plt.figure(figsize=(15, 10))
plt.subplots_adjust(top=1.25, bottom=1.2)

# Iterate over each company
for i, company in enumerate(company_list, 1):
    plt.subplot(2, 2, i)
    
    # Filter data for the current company
    company_data = df[df['company_name'] == company]
    
    # Plot the high and low prices over time
    plt.plot(company_data['Date'], company_data['High'], color='lime', label='High')
    plt.plot(company_data['Date'], company_data['Low'], color='red', label='Low')
    
    plt.ylabel('Price')
    plt.xlabel(None)
    plt.title(f"High and Low Prices of {company}")
    plt.legend()
    
    # Set x-axis tick frequency to display years only
    plt.gca().xaxis.set_major_locator(mdates.YearLocator())
    plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y'))

plt.tight_layout()
plt.show()

# %%
# List of unique companies
company_list = df['company_name'].unique()

# Set up the plot
plt.figure(figsize=(15, 10))
plt.subplots_adjust(top=1.25, bottom=1.2)

# Iterate over each company
for i, company in enumerate(company_list, 1):
    plt.subplot(2, 2, i)
    
    # Filter data for the current company
    company_data = df[df['company_name'] == company]
    
    # Plot the high and low prices over time
    plt.plot(company_data['Date'], company_data['Open'], color='lime', label='Open')
    plt.plot(company_data['Date'], company_data['Close'], color='red', label='Close')
    
    plt.ylabel('Price')
    plt.xlabel(None)
    plt.title(f"High and Low Prices of {company}")
    plt.legend()
    
    # Set x-axis tick frequency to display years only
    plt.gca().xaxis.set_major_locator(mdates.YearLocator())
    plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y'))

plt.tight_layout()
plt.show()

# %% [markdown]
# Let's see changes in stock price in last year.

# %%
# Assuming 'Date' is in datetime format
df['Date'] = pd.to_datetime(df['Date'])

# List of unique companies in the 'company_name' column
company_list = df['company_name'].unique()

# Set up the plot
plt.figure(figsize=(15, 10))
plt.subplots_adjust(top=1.25, bottom=1.2)

# Iterate over each company
for i, company in enumerate(company_list, 1):
    plt.subplot(2, 2, i)
    
    # Filter data for the current company and the years 2023-2024
    company_data = df[(df['company_name'] == company) & (df['Date'].dt.year.between(2023, 2024))]
    
    # Plot the 'Adj Close' column with the original 'Date' values
    plt.plot(company_data['Date'], company_data['Adj Close'])
    
    plt.ylabel(None)
    plt.xlabel(None)
    plt.title(f"Closing Price of {company}")

    # Set x-axis tick frequency to display years only
    plt.gca().xaxis.set_major_formatter(DateFormatter('%Y-%m'))
    # Set y-axis tick format to display values in dollars
    plt.gca().yaxis.set_major_formatter('${x:,.0f}')

plt.tight_layout()
plt.show()

# %% [markdown]
# Volume of Sales

# %% [markdown]
# Volume is the amount of an asset or security that changes hands over some period of time, often over the course of a day. For instance, the stock trading volume would refer to the number of shares of security traded between its daily open and close. Trading volume, and changes to volume over the course of time, are important inputs for technical traders.

# %%
import matplotlib.dates as mdates

# Set up the plot
plt.figure(figsize=(15, 10))
plt.subplots_adjust(top=1.25, bottom=1.2)

# Iterate over each company
for i, company in enumerate(company_list, 1):
    plt.subplot(2, 2, i)
    
    # Filter data for the current company
    company_data = df[df['company_name'] == company]
    
    # Plot the total volume of stock being traded each day
    plt.plot(company_data['Date'], company_data['Volume'])
    
    plt.ylabel('Volume')
    plt.xlabel(None)
    plt.title(f"Sales Volume for {company}")

    # Use DateFormatter for proper date formatting
    plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y'))

plt.tight_layout()
plt.show()

# %% [markdown]
# The plots of sales volume for shares provide valuable insights into market activity and investor sentiment. What can we see:
#
# Market Activity: Sales volume plots show the level of trading activity for a particular stock over time. High trading volume often indicates increased interest and activity in the stock, while low volume may suggest indifference or lack of interest.
#
# Liquidity: Volume plots provide an indication of a stock's liquidity, or how easily it can be bought or sold without significantly impacting its price. Higher liquidity is generally preferred by investors as it allows for smoother and more efficient trading.
#
# Price Movements Confirmation: Changes in sales volume often precede price movements. For example, a significant increase in volume accompanied by a price increase may suggest bullish sentiment, while a decrease in volume with a price decrease could signal bearish sentiment.
#
# Market Sentiment: Volume plots can also reflect market sentiment and investor confidence. Sustained high volume during a price rally indicates strong bullish sentiment, while high volume during a price decline may indicate panic selling or capitulation.
#
# Confirmation of Trends: Volume plots can confirm or contradict trends observed in price charts. For example, if a stock price is rising but volume is declining, it may signal weakening momentum and potential reversal.

# %% [markdown]
# The plot reveals an interesting observation: in three companies, we observe a surge in trading volume during the period when prices fell between 2023 and 2024.
#
# The observation of high volume accompanying a decline in stock prices is significant and can suggest several potential factors at play:
#
# Panic Selling: High volume during a decline in stock prices may indicate panic selling among investors. When investors become fearful of further losses or negative news, they may rush to sell their shares, resulting in increased trading volume.
#
# Market Sentiment Shift: A notable increase in volume during a downturn could signify a shift in market sentiment. It suggests that a large number of investors are actively participating in the market, either by selling off their positions or taking short positions, reflecting a widespread pessimistic outlook on the stock or market.
#
# Technical Signals: High volume during a decline can confirm technical signals such as breakdowns from key support levels or bearish chart patterns. It adds weight to the bearish signal and indicates strong momentum in the direction of the decline.
#
# Corporate Events or News: Significant corporate events or negative news releases can trigger both a decline in stock prices and a surge in trading volume. This could include earnings misses, regulatory issues, product recalls, or management changes.
#
# Profit-Taking: In some cases, high volume during a decline may also be attributed to profit-taking by investors who had previously enjoyed gains in the stock. They may choose to sell their positions to lock in profits before the decline worsens.
#
# There are also some specific reasons. For instance, the reason for the very high volume in Solaredge at the end of 2023 is because the company left the S&P 500 index. It transpired that everyone who had invested in the S&P 500 index sold their shares during this period, while those who ranked lower in the index bought shares.

# %% [markdown]
# Now that we've seen the visualizations for the closing price and the volume traded each day, let's go ahead and caculate the moving average for the stock.

# %% [markdown]
# 2. What was the moving average of the various stocks?

# %% [markdown]
# The moving average (MA) is a widely used technical analysis tool that smooths out price data by creating a constantly updated average price. It provides traders and analysts with a clearer picture of the underlying trend by eliminating short-term fluctuations or noise in the data.
#
# In the provided code, the moving averages for different time periods (10, 20, and 50 days) are calculated for each company's stock prices. The moving averages are plotted alongside the actual adjusted closing prices for visual comparison. This allows analysts to observe how the current price compares to historical averages over different time frames.
#
# By plotting the moving averages, we can identify trends and potential reversal points in the stock prices. When the actual prices cross above or below the moving averages, it may indicate a change in trend direction. Additionally, the relative positions of different moving averages can provide insights into the strength and duration of the prevailing trend.

# %%
# Set 'Date' column as the index
df.set_index('Date', inplace=True)

# List of unique companies in the 'company_name' column
company_list = df['company_name'].unique()

# List of moving average days
ma_days = [10, 20, 50]

# Calculate moving averages for each company
for ma in ma_days:
    for company in company_list:
        column_name = f"MA for {ma} days"
        df.loc[df['company_name'] == company, column_name] = df.loc[df['company_name'] == company, 'Adj Close'].rolling(ma).mean()

# Plotting
fig, axes = plt.subplots(nrows=2, ncols=2)
fig.set_figheight(10)
fig.set_figwidth(15)

for i, company in enumerate(company_list, 1):
    ax = axes[(i - 1) // 2, (i - 1) % 2]
    columns_to_plot = ['Adj Close'] + [f"MA for {ma} days" for ma in ma_days]
    df[df['company_name'] == company][columns_to_plot].plot(ax=ax)
    ax.set_title(company)
    ax.xaxis.set_major_formatter(mdates.DateFormatter('%Y'))

fig.tight_layout()
plt.show()

# %% [markdown]
# We see in the graph that the best values to measure the moving average are 10 and 20 days because we still capture trends in the data without noise.
# This insight suggests that these shorter-term moving averages may be more suitable for identifying meaningful patterns and trends in the stock prices.

# %% [markdown]
# 3. What was the daily return of the stock on average?

# %% [markdown]
# Now that we've done some baseline analysis, let's go ahead and dive a little deeper. We're now going to analyze the risk of the stock. In order to do so we'll need to take a closer look at the daily changes of the stock, and not just its absolute value.
# The daily return of a stock on average refers to the average percentage change in the stock's price from one day to the next over a specific period of time. It is calculated by taking the average of the daily percentage changes in the stock's price over that period.

# %%
# Calculate daily returns for each company
for company in company_list:
    df.loc[df['company_name'] == company, 'Daily Return'] = df.loc[df['company_name'] == company, 'Adj Close'].pct_change()

# Plotting
fig, axes = plt.subplots(nrows=2, ncols=2)
fig.set_figheight(10)
fig.set_figwidth(15)

for i, company in enumerate(company_list, 1):
    ax = axes[(i - 1) // 2, (i - 1) % 2]
    df[df['company_name'] == company]['Daily Return'].plot(ax=ax, legend=True, linestyle='--', marker='o')
    ax.set_title(company)

fig.tight_layout()
plt.show()

# %% [markdown]
# We can learn from this plot:
# Volatility: The extent of fluctuation or variability in the daily returns indicates the volatility of the stock. A wider range of values indicates higher volatility, while a narrower range suggests lower volatility.
#
# Trends: Patterns in the daily returns can reveal trends in the stock's performance over time. Positive daily returns indicate days when the stock price increased, while negative returns indicate days when the stock price decreased.
#
# Outliers: Extreme values in the daily returns may represent outliers, indicating days with significant price movements or unusual market events. These outliers can provide insights into specific events or news affecting the stock's performance.
#
# Correlation: Examining the daily returns of multiple companies simultaneously can reveal correlations or relationships between their performances. Positive correlations suggest that the stocks tend to move in the same direction, while negative correlations indicate opposite movements.
#
# For instance, in Enphase Energy, we observe outliers during periods of surges in stock prices. The plots for SolarEdge and SunPower exhibit similarities, depicting numerous days with significant price movements. It indicates for high correlation between these companies. In the case of First Solar, the largest unusual market events are noticeable in 2018 and the first part of 2023.

# %% [markdown]
# Great, now let's get an overall look at the average daily return using a histogram.

# %%
import seaborn as sns

# Plotting histograms with a line plot
plt.figure(figsize=(12, 9))

for i, company in enumerate(company_list, 1):
    plt.subplot(2, 2, i)
    daily_returns = df[df['company_name'] == company]['Daily Return']
    
    # Plot histogram
    sns.histplot(daily_returns, bins=50, kde=True, color='blue', stat='density',label='Daily Return Histogram')
    
    # Calculate mean or median
    mean_return = daily_returns.mean()
    median_return = daily_returns.median()
    
    
    plt.xlabel('Daily Return')
    plt.ylabel('Count')
    plt.title(f'{company}')
    plt.legend()
    plt.grid()

plt.tight_layout()
plt.show()

# %% [markdown]
# The analysis of the histogram provides several key insights:
#
# Central Tendency: Across all companies, the histogram illustrates a normal distribution of daily returns, suggesting that returns are concentrated around a specific value. Notably, First Solar exhibits a more pronounced central tendency, with returns predominantly falling within the range of -0.1 to 0.1.
#
# Skewness: Skewness is observed in the distribution of returns for all companies. SolarEdge and SunPower display right-skewed distributions, indicating a higher frequency of positive returns. Conversely, Enphase and First Solar exhibit left-skewed distributions, suggesting a prevalence of negative returns.
#
# Dispersion: The spread or dispersion of daily returns varies among companies. SunPower demonstrates the widest spread, indicative of higher volatility in returns. Conversely, First Solar exhibits the narrowest spread, implying lower volatility.

# %% [markdown]
# 4. What was the correlation between different stocks closing prices?

# %% [markdown]
# We want to analyze the returns of all the stocks in our list. We can compare the daily percentage return of two stocks to check how correlated.

# %%
# Drop NaN values in 'Daily Return' column
df_cleaned = df.dropna(subset=['Daily Return'])

# Group by 'Date' and 'company_name', calculate mean daily return
grouped_df = df_cleaned.groupby(['Date', 'company_name'])['Daily Return'].mean().reset_index()
grouped_df.head()
# Out:
#         Date    company_name  Daily Return
# 0 2017-01-04  Enphase Energy      0.095238
# 1 2017-01-04     First Solar      0.018783
# 2 2017-01-04       Solaredge      0.090909
# 3 2017-01-04        SunPower      0.033577
# 4 2017-01-05  Enphase Energy     -0.026087

# %%
# Pivot the DataFrame to create the new structure for dailyreturn
pivot_df = grouped_df.pivot_table(index='Date', columns='company_name', values='Daily Return')

# Display the new DataFrame
print(pivot_df.head())
# Out:
# company_name  Enphase Energy  First Solar  Solaredge  SunPower
# Date
# 2017-01-04          0.095238     0.018783   0.090909  0.033577
# 2017-01-05         -0.026087    -0.008487  -0.041667  0.007062
# 2017-01-06         -0.008929    -0.016529  -0.003623 -0.011220
# 2017-01-09          0.000000     0.007503  -0.018182  0.014184
# 2017-01-10          0.018018    -0.005362   0.003704  0.012587

# %%
grouped_close_df = df_cleaned.groupby(['Date', 'company_name'])['Adj Close'].mean().reset_index()

# Pivot the DataFrame to create the new structure for dailyreturn
closing_df = grouped_close_df.pivot_table(index='Date', columns='company_name', values='Adj Close')

# Display the new DataFrame
print(closing_df.head())
# Out:
# company_name  Enphase Energy  First Solar  Solaredge  SunPower
# Date
# 2017-01-04              1.15    34.169998      14.40  4.636542
# 2017-01-05              1.12    33.880001      13.80  4.669286
# 2017-01-06              1.11    33.320000      13.75  4.616896
# 2017-01-09              1.11    33.570000      13.50  4.682384
# 2017-01-10              1.13    33.389999      13.55  4.741323

# %%
# Comparing Enphase Energy to itself should show a perfectly linear relationship
sns.jointplot(x='Enphase Energy', y='Enphase Energy', data=pivot_df, kind='scatter', color='seagreen')

# %% [markdown]
# First I checked one company - Enphase Energy. This generate a line plot showing how the closing price of Enphase Energy has changed over time.

# %%
sns.jointplot(x='Enphase Energy', y='Solaredge', data=pivot_df, kind='scatter')

# %% [markdown]
# Now, we can observe that if two stocks are perfectly (and positively) correlated with each other, a linear relationship between their daily return values should be evident. Let's proceed to check the correlation of daily returns across all companies.

# %%
sns.pairplot(pivot_df, kind='reg')

# %% [markdown]
# Above, we can observe the relationships in daily returns between all the stocks. There is a strong positive correlation between the daily returns of all the companies. When the points cluster around a straight line, it suggests a strong linear relationship between the daily returns of the companies. This positive correlation indicates that when one stock's return is high, the others tend to have high returns as well, while a negative correlation suggests the opposite.
#
# Let's proceed to explore more plots.

# %%
# Set up our figure by naming it returns_fig, call PairPLot on the DataFrame
return_fig = sns.PairGrid(pivot_df.dropna())

# Using map_upper we can specify what the upper triangle will look like.
return_fig.map_upper(plt.scatter, color='purple')

# We can also define the lower triangle in the figure, inclufing the plot type (kde) 
# or the color map (BluePurple)
return_fig.map_lower(sns.kdeplot, cmap='cool_d')

# Finally we'll define the diagonal as a series of histogram plots of the daily return
return_fig.map_diag(plt.hist, bins=30)

# %% [markdown]
# Mapping kernel density estimate (KDE) to the lower triangle of the PairGrid means that for each pair of variables in the dataset, a smooth curve representing the estimated probability density function (PDF) is plotted. Interpreting this part of the plot involves understanding the shape and distribution of these KDE curves. Here's how to interpret it:
#
# Shape of the Curves: The shape of the KDE curves gives insights into the distribution of the data. A peak in the curve indicates where the data is most concentrated, while the width of the curve represents the variability or spread of the data.
# For instance, when comparing Enphase Energy and SolarEdge, we observe a higher concentration of data with narrower curves. In contrast, comparing Enphase Energy with SunPower reveals greater variability and spread in the data.
#
# Skewness and Tails: Some pairs of companies exhibit symmetric distributions, such as Enphase Energy and SolarEdge, or SolarEdge and SunPower. However, other pairs, like SolarEdge and First Solar, or Enphase Energy and SunPower, display asymmetric distributions. Additionally, the presence of tails, representing outliers or extreme values in the data, is noticeable in all plots.

# %% [markdown]
# Let's examine the correlation of stock returns and stock closing prices using heatmaps.

# %%
plt.figure(figsize=(16, 12))

plt.subplot(2, 2, 1)
heatmap = sns.heatmap(pivot_df.corr(), annot=True, cmap='viridis', annot_kws={"size": 10})
heatmap.set_xticklabels(heatmap.get_xticklabels(), rotation=45)
heatmap.set_yticklabels(heatmap.get_yticklabels(), rotation=0)
plt.title('Correlation of Stock Return')

plt.subplot(2, 2, 2)
heatmap = sns.heatmap(closing_df.corr(), annot=True, cmap='viridis', annot_kws={"size": 10})
heatmap.set_xticklabels(heatmap.get_xticklabels(), rotation=45)
heatmap.set_yticklabels(heatmap.get_yticklabels(), rotation=0)
plt.title('Correlation of Stock Closing Price')

plt.tight_layout()
plt.show()

# %% [markdown]
# The correlation of stock returns: In all of the companies, we can observe a strong positive correlation. The highest correlation is between SunPower and First Solar at 0.61, while the weakest correlation is between First Solar and Enphase Energy at 0.47.
#
# The correlation of stock closing prices: We can observe a really high correlation between SolarEdge and Enphase Energy at 0.91. All other companies are positively highly correlated as well. The weakest correlation is between SunPower and First Solar at 0.31.

# %% [markdown]
# 5. How much value do we put at risk by investing in a particular stock?

# %% [markdown]
# There are many ways we can quantify risk, one of the most basic ways using the information we've gathered on daily percentage returns is by comparing the expected return with the standard deviation of the daily returns.

# %%
import numpy as np

rets = pivot_df.dropna()

area = np.pi * 20

plt.figure(figsize=(10, 8))
plt.scatter(rets.mean(), rets.std(), s=area)
plt.xlabel('Expected return')
plt.ylabel('Risk')

for label, x, y in zip(rets.columns, rets.mean(), rets.std()):
    plt.annotate(label, xy=(x, y), xytext=(50, 50), textcoords='offset points', ha='right', va='bottom', 
                 arrowprops=dict(arrowstyle='-', color='blue', connectionstyle='arc3,rad=-0.3'))

# %% [markdown]
# On this plot, each point represents a different stock. The x-axis indicates the expected return, which is the mean of the daily percentage returns for each stock. The y-axis represents the risk, which is measured by the standard deviation of the daily percentage returns.
#
# By analyzing this plot, we can observe the risk-return tradeoff for each stock.
# We can observe that Enphase Energy exhibits the highest expected returns, accompanied by the highest level of risk. Conversely, stocks of First Solar demonstrate lower expected returns but also lower risk. SunPower's stocks are characterized by a low expected return coupled with very high risk. Finally, SolarEdge exhibits a moderate level of both expected return and risk.
